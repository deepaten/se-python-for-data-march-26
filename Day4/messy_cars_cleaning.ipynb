# %%
import numpy as np
import pandas as pd

# %%
messy_df = pd.read_csv("messy-cars.csv")
print(messy_df.head())
# Out:
#   Car_num      Brand        Mod    Yr    Money     Miles   Color
# 0  CAR001      Honda      Coupe  2022      NaN  197300.0   White
# 1  CAR002  Chevrolet      Coupe  2009  42065.0  119752.0    Blue
# 2  CAR003        BMW        SUV  2022  31557.0   53984.0     Red
# 3  CAR004  Chevrolet  Hatchback  2001  38763.0   45774.0  Yellow
# 4  CAR005  Chevrolet  Hatchback  2006  37606.0    7568.0   Green

# %%
# Check the shape
print(messy_df.shape)

# check the columns
print(messy_df.columns)

#check the statistical summary of the cars data
print(messy_df.describe())

#check the missing values and details of contents if nulls
print(messy_df.info())

#cars data
print(messy_df)
# Out:
# (25, 7)
# Index(['Car_num', 'Brand', 'Mod', 'Yr', 'Money', 'Miles', 'Color'], dtype='str')
#                 Yr         Money          Miles
# count    25.000000     20.000000      22.000000
# mean   2008.440000  31240.950000   99637.545455
# std       8.958609  11484.851242   61057.474473
# min    1996.000000  13529.000000    7568.000000
# 25%    2001.000000  25247.750000   44821.500000
# 50%    2008.000000  29288.000000  114620.000000
# 75%    2016.000000  39588.500000  139416.500000
# max    2023.000000  56214.000000  198664.000000
# <class 'pandas.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Car_num  25 non-null     str
#  1   Brand    21 non-null     str
#  2   Mod      25 non-null     str
#  3   Yr       25 non-null     int64
#  4   Money    20 non-null     float64
#  5   Miles    22 non-null     float64
#  6   Color    22 non-null     str
# ...

# %%
df_brand_clean = messy_df.dropna(subset=["Brand"])
print(df_brand_clean.info())
# Out:
# <class 'pandas.DataFrame'>
# Index: 21 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Car_num  21 non-null     str
#  1   Brand    21 non-null     str
#  2   Mod      21 non-null     str
#  3   Yr       21 non-null     int64
#  4   Money    17 non-null     float64
#  5   Miles    18 non-null     float64
#  6   Color    20 non-null     str
# dtypes: float64(2), int64(1), str(4)
# memory usage: 1.3 KB
# None

# %%
print(df_brand_clean.sort_values(by= "Brand"))
# Out:
#    Car_num      Brand          Mod    Yr    Money     Miles   Color
# 11  CAR012        BMW        Coupe  1998  29276.0   44504.0   Black
# 2   CAR003        BMW          SUV  2022  31557.0   53984.0     Red
# 6   CAR007        BMW    Hatchback  2002  34127.0  198664.0   White
# 7   CAR008        BMW    Hatchback  2009      NaN  138767.0  Yellow
# 8   CAR009        BMW        Sedan  1997      NaN  129375.0   Black
# 1   CAR002  Chevrolet        Coupe  2009  42065.0  119752.0    Blue
# 3   CAR004  Chevrolet    Hatchback  2001  38763.0   45774.0  Yellow
# 4   CAR005  Chevrolet    Hatchback  2006  37606.0    7568.0   Green
# 21  CAR022  Chevrolet          SUV  2023      NaN  109488.0    Blue
# 12  CAR013  Chevrolet  Convertible  2012  28247.0  169231.0     NaN
# 5   CAR006       Ford        Coupe  2023  16534.0  125151.0   Black
# 13  CAR014       Ford        Sedan  2002  29300.0       NaN  Yellow
# 20  CAR021       Ford        Sedan  2016  44099.0   69505.0     Red
# ...
